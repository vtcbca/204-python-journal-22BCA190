# %%
import pandas as pd

# %% [markdown]
#  ## CREATE DATAFRAME FROM LIST

# %%
l=[1,"om",2,"Sai",3,"Ram"]
l
# Out:
# [1, 'om', 2, 'Sai', 3, 'Ram']

# %%
import numpy as np

# %%
la=np.array(l)
la
# Out:
# array(['1', 'om', '2', 'Sai', '3', 'Ram'], dtype='<U11')

# %%
print(type(la))
type(l)
# Out:
# <class 'numpy.ndarray'>
# list

# %%
ldf=pd.DataFrame(l) 
ldf
# Out:
#      0
# 0    1
# 1   om
# 2    2
# 3  Sai
# 4    3
# 5  Ram

# %%
ldf=pd.DataFrame([1,"om",2,"sai",3,"ram"])
ldf
# Out:
#      0
# 0    1
# 1   om
# 2    2
# 3  sai
# 4    3
# 5  ram

# %% [markdown]
# #### DIFFERENCE:
#
# 1. We create list and print it. Check the output, it show output in list.
# 2. We create array and show output in array format.
# 3. Last we create dataframe and show output in tabular format.
#
# So When we want to access data in tabular format, we have to use DataFrame.
#
# We create dataframe from list, list of list, dictinary, array or external file format like csv, excel, json, etc....
#
# We do all the operation which we perform in excel sheet. Then why we require to create dataframe?
#
# Sometime excel sheets are readonly we are not change content, in such situation we have to read it in dataframe and perform operation or analysis on it.

# %% [markdown]
# ## CREATE DATAFRAME FROM NESTED LIST

# %%
nl=[
    [1,"om"],
    [2,"sai"],
    [3,"ram"]
]

# %%
nldf=pd.DataFrame(nl)
print(nldf)
# Out:
#    0    1
# 0  1   om
# 1  2  sai
# 2  3  ram

# %% [markdown]
# ## PRINT DATATYPE OF TABLE COLUMNS

# %%
nldf.dtypes  #dtype attribute of dataframe
# Out:
# 0     int64
# 1    object
# dtype: object

# %%
print(type(nldf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### dtype Vs type
#
# - *dtype:* Give the datatype of column value.
# - *type:* Give the datatype of variable

# %% [markdown]
# ## CHANGE COLUMN NAME

# %%
nldf=pd.DataFrame(nl,columns=["ID","Name"])
nldf=
# Out:
#    ID Name
# 0   1   om
# 1   2  sai
# 2   3  ram

# %% [markdown]
# ## CHANGE ROW INDEX NAME

# %%
nldf=pd.DataFrame(nl,index=["row1","row2","row3"])
nldf
# Out:
#       0    1
# row1  1   om
# row2  2  sai
# row3  3  ram

# %% [markdown]
# ## CREATE DATA FRAME USING DICTONARY

# %%
d={"ID":[21,22,23],
   "Name":["om","sai","ram"],
   "%age":[82.82,75.68,90.67]
  } 

# key becomes column heading and value becomes value of that column.

# %%
ddf=pd.DataFrame(d)
ddf
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 1  22  sai  75.68
# 2  23  ram  90.67

# %%
d1={"ID":[21,22,23,24],
   "Name":["om","sai","ram","radha"],
   "%age":[82.82,75.68,90.67,75.75]
  } 
d1df=pd.DataFrame(d1)
d1df
# Out:
#    ID   Name   %age
# 0  21     om  82.82
# 1  22    sai  75.68
# 2  23    ram  90.67
# 3  24  radha  75.75

# %% [markdown]
# ##  List column name of dataframe
#
# Following way we print the name of columns

# %%
ddf.columns
# Out:
# Index(['ID', 'Name', '%age'], dtype='object')

# %%
ddf.columns.values
# Out:
# array(['ID', 'Name', '%age'], dtype=object)

# %%
ddf.columns.values.tolist()
# Out:
# ['ID', 'Name', '%age']

# %%
list(ddf)
# Out:
# ['ID', 'Name', '%age']

# %%
 for c in ddf:
    print(c)
# Out:
# ID
# Name
# %age

# %%
[ c for c in ddf ] ## List comprehension
# Out:
# ['ID', 'Name', '%age']

# %% [markdown]
# List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.

# %% [markdown]
# ## How to access single column?

# %%
ddf
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 1  22  sai  75.68
# 2  23  ram  90.67

# %%
ddf["Name"]
# Out:
# 0     om
# 1    sai
# 2    ram
# Name: Name, dtype: object

# %% [markdown]
# ### How to access multiple column? OR Selectiong only some columns from dataframe.
#
# - To access multiple column we write columns name in [ [columnname, columname,.....] ]
#
#
#
# - When using bracket-indexing without the .loc or .iloc accessors, the result returned can be an individual value, Pandas Series, or Pandas DataFrame.
#
#
# - To ensure the return value is a DataFrame, use a nested list within square brackets

# %%
ddf [ [ "ID","Name" ] ]
# Out:
#    ID Name
# 0  21   om
# 1  22  sai
# 2  23  ram

# %% [markdown]
# ## Accessors : Extract values from dataframe
# - A more efficient and more programmatically reusable method of accessing data in a DataFrame is by using accessors
#
#
#
#     1 .loc:  accesses using lables
#
#     2 .iloc: accesses using index positions
#
#
# - Both accessors use left bracket, row specifier, comma, column specifier, right bracket as syntax

# %% [markdown]
# ### iloc : Index based or Location Based extraction
#
# - Python location-based indexing begins with [0].
#
# - It is working same as list and other data structure.
#
# - You can use location-based indexing to query pandas dataframes using the attribute .iloc and providing the row and column selection as ranges (i.e. start and stop locations along the rows and columns).
#
# - Dataframe.iloc[] method is used when the index label of a data frame is something other than numeric series of 0, 1, 2, 3….n or in case the user doesn’t know the index label
#
#
# **dataframe.iloc [ index of row , index of column ]**

# %%
ddf
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 1  22  sai  75.68
# 2  23  ram  90.67

# %% [markdown]
# #### Print all data

# %%
ddf.iloc[:]
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 1  22  sai  75.68
# 2  23  ram  90.67

# %%
ddf.iloc[:,:]
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 1  22  sai  75.68
# 2  23  ram  90.67

# %% [markdown]
# #### Give value of second row second column

# %%
ddf.iloc[1,1]
# Out:
# 'sai'

# %% [markdown]
# #### Print first two column of dataframe for all row

# %%
ddf.iloc[:,0:2]
# Out:
#    ID Name
# 0  21   om
# 1  22  sai
# 2  23  ram

# %% [markdown]
# Other important example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### loc : LABEL BASED EXTRACTION
#
# - The **loc** property is used to access a group of rows and columns by label(s) or a boolean array.
#
#
# - **.loc[ ]** is primarily label based but may also be used with a Boolean array.
#
#
# **Allowed inputs are:**
#
# - A single label, e.g., 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
#
# - A list or array of labels, e.g. ['a', 'b', 'c'].
#
#
# - A slice object with labels, e.g., 'a':'f'.

# %% [markdown]
# #### Display  ID of first row

# %%
ddf.loc[0,"ID"]
# Out:
# 21

# %% [markdown]
# #### Display Name and Percentage of all row

# %%
ddf.loc[:,"Name":"%age"]
# Out:
#   Name   %age
# 0   om  82.82
# 1  sai  75.68
# 2  ram  90.67

# %% [markdown]
# #### Display ID and Percentage of all row

# %%
#ddf.loc[:,"ID","%age"] # WRONG WAY

ddf.loc[:, ['ID','%age']]
# Out:
#    ID   %age
# 0  21  82.82
# 1  22  75.68
# 2  23  90.67

# %%
ddf.loc[:1,['ID','%age']]  # read value of o and 1 row for ID and %age column
# Out:
#    ID   %age
# 0  21  82.82
# 1  22  75.68

# %% [markdown]
# ## Access Specific Row Based on Condition

# %%
ddf [ "%age" ] > 80
# Out:
# 0     True
# 1    False
# 2     True
# Name: %age, dtype: bool

# %%
ddf[ ddf["%age"]  > 80 ]
# Out:
#    ID Name   %age
# 0  21   om  82.82
# 2  23  ram  90.67

# %% [markdown]
# ## Access perticular value of cell like column =name and row=0

# %%
ddf["Name"][0] # In first [] give column name and second [] give row index (name)
# Out:
# 'om'

# %% [markdown]
# ### Print first name and id of students whose percentage > 80

# %%
ddf[ddf["%age"] > 80].loc[0,["ID","Name"]]
# Out:
# ID      21
# Name    om
# Name: 0, dtype: object

# %% [markdown]
# ## Insert row

# %%
ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]]))
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11576\1115175676.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]]))

# %%
ddf2
# Out:
#      ID Name   %age     0      1      2
# 0  21.0   om  82.82   NaN    NaN    NaN
# 1  22.0  sai  75.68   NaN    NaN    NaN
# 2  23.0  ram  90.67   NaN    NaN    NaN
# 0   NaN  NaN    NaN  24.0  Radha  65.57
# 1   NaN  NaN    NaN  25.0  Gopal  55.58

# %%
ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]],columns=["ID","Name","%age"]))
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11576\1829413381.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]],columns=["ID","Name","%age"]))

# %%
ddf2
# Out:
#    ID   Name   %age
# 0  21     om  82.82
# 1  22    sai  75.68
# 2  23    ram  90.67
# 0  24  Radha  65.57
# 1  25  Gopal  55.58

# %% [markdown]
# Here it give index (row name), from 0. It is not correct way. It must be 3 and 4 not 0,1
#
# ##### For index continuation, we have to pass "ignore_index=True" parameter during dataframe creation. By default it is false.

# %%
ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]],columns=["ID","Name","%age"]), ignore_index=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11576\3738098310.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ddf2=ddf.append(pd.DataFrame([[24,"Radha",65.57],[25,"Gopal",55.58]],columns=["ID","Name","%age"]), ignore_index=True)

# %%
ddf2
# Out:
#    ID   Name   %age
# 0  21     om  82.82
# 1  22    sai  75.68
# 2  23    ram  90.67
# 3  24  Radha  65.57
# 4  25  Gopal  55.58

# %% [markdown]
# ### Print dataframe without index

# %%
ddf2 = ddf2.to_string(index=False)
print(ddf2)
# Out:
#  ID  Name  %age
#  21    om 82.82
#  22   sai 75.68
#  23   ram 90.67
#  24 Radha 65.57
#  25 Gopal 55.58

# %%
type(ddf2)
# Out:
# str

# %% [markdown]
# You can use DataFrame.to_string(index=False) on the DataFrame object to print.
#
# To result DataFrame.to_string() function is a string of the DataFrame without indices. The column names are retained as the first row.

# %%
df=pd.read_csv("C:\Python310\csv\customers.csv")
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %% [markdown]
# ## READ CSV FILE IN PYTHON
#
# - read_csv( ) is used to read the csv file in python.

# %%
df=pd.read_csv("C:\Python310\csv\customers.csv")
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
dfcsv=pd.read_csv("C:\Python310\csv\customers.csv",nrows=10)
dfcsv
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
# 6           7  Female   35              31000                       6
# 7           8  Female   23              84000                      94
# 8           9    Male   64              97000                       3
# 9          10  Female   30              98000                      72
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# ...

# %%
dfcsv=pd.read_csv("C:\Python310\csv\customers.csv",usecols=[1,2,5])
dfcsv
# Out:
#       Gender  Age     Profession
# 0       Male   19     Healthcare
# 1       Male   21       Engineer
# 2     Female   20       Engineer
# 3     Female   23         Lawyer
# 4     Female   31  Entertainment
# ...      ...  ...            ...
# 1995  Female   71         Artist
# 1996  Female   91         Doctor
# 1997    Male   87     Healthcare
# 1998    Male   77      Executive
# 1999    Male   90  Entertainment
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## head( ) && tail( )

# %%
dfcsv=pd.read_csv("C:\Python310\csv\customers.csv")
dfcsv
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
dfcsv.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
dfcsv.head(8)
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
# 6           7  Female   35              31000                       6
# 7           8  Female   23              84000                      94
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6
# 5         Artist                0            2
# ...

# %%
dfcsv.tail()
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2

# %%
dfcsv.tail(8)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1992        1993    Male   94             181183                      24
# 1993        1994  Female   64             175254                     100
# 1994        1995  Female   19              54121                      89
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 1992      Marketing                9            3
# 1993         Artist                9            5
# 1994       Engineer                6            3
# 1995         Artist                8            7
# 1996         Doctor                7            7
# ...

# %% [markdown]
# ### Difference between dataframe.columname Vs dataframe [ [ columnname ]]

# %%
dfcsv.Age
# Out:
# 0       19
# 1       21
# 2       20
# 3       23
# 4       31
#         ..
# 1995    71
# 1996    91
# 1997    87
# 1998    77
# 1999    90
# Name: Age, Length: 2000, dtype: int64

# %%
dfcsv["Age"]
# Out:
# 0       19
# 1       21
# 2       20
# 3       23
# 4       31
#         ..
# 1995    71
# 1996    91
# 1997    87
# 1998    77
# 1999    90
# Name: Age, Length: 2000, dtype: int64

# %%
dfcsv[["Age"]]
# Out:
#       Age
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
# ...   ...
# 1995   71
# 1996   91
# 1997   87
# 1998   77
# 1999   90
#
# [2000 rows x 1 columns]

# %%
print(type(dfcsv[["Age"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(dfcsv["Age"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dfcsv.loc[:5]
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6
# 5         Artist                0            2

# %%
dfcsv.iloc[:5]
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
dfcsv.Profession
# Out:
# 0          Healthcare
# 1            Engineer
# 2            Engineer
# 3              Lawyer
# 4       Entertainment
#             ...
# 1995           Artist
# 1996           Doctor
# 1997       Healthcare
# 1998        Executive
# 1999    Entertainment
# Name: Profession, Length: 2000, dtype: object

# %%
dfcsv["Profession"]
# Out:
# 0          Healthcare
# 1            Engineer
# 2            Engineer
# 3              Lawyer
# 4       Entertainment
#             ...
# 1995           Artist
# 1996           Doctor
# 1997       Healthcare
# 1998        Executive
# 1999    Entertainment
# Name: Profession, Length: 2000, dtype: object

# %%
dfcsv[["Profession","Gender","Age"]]
# Out:
#          Profession  Gender  Age
# 0        Healthcare    Male   19
# 1          Engineer    Male   21
# 2          Engineer  Female   20
# 3            Lawyer  Female   23
# 4     Entertainment  Female   31
# ...             ...     ...  ...
# 1995         Artist  Female   71
# 1996         Doctor  Female   91
# 1997     Healthcare    Male   87
# 1998      Executive    Male   77
# 1999  Entertainment    Male   90
#
# [2000 rows x 3 columns]

# %%
dfcsv[dfcsv["Annual Income ($)"] > 50000]
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 5              6  Female   22              58000                      76
# 7              8  Female   23              84000                      94
# 8              9    Male   64              97000                       3
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
dfcsv[dfcsv["Age"] > 20]
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1              2    Male   21              35000                      81
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# 5              6  Female   22              58000                      76
# 6              7  Female   35              31000                       6
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
dfcsv[(dfcsv["Age"] > 20) & (dfcsv['Gender']=="Male")]
# Out:
#       CustomerID Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1              2   Male   21              35000                      81
# 8              9   Male   64              97000                       3
# 10            11   Male   67               7000                      14
# 14            15   Male   37              19000                      13
# 15            16   Male   22              51000                      79
# ...          ...    ...  ...                ...                     ...
# 1987        1988   Male   63              59244                      80
# 1992        1993   Male   94             181183                      24
# 1997        1998   Male   87              90961                      14
# 1998        1999   Male   77             182109                       4
# 1999        2000   Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 1          Engineer                3            3
# ...
